# %% [markdown]
# # Final Capstone Project

# %% [markdown]
# This notebook is going to be the final notebook for the capstone project.

# %% [markdown]
# ## Importing appropriate packages

# %%
# standard packages
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# packages for clustering
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as hc
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE

# preprocessing packages
from sklearn.preprocessing import MinMaxScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geocoder # to get coordinates

import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import folium # map rendering library

print('All packages are imported.')
# Out:
# All packages are imported.

# %% [markdown]
# ## Webscrape a webpage for each of the zipcodes of New York City

# %% [markdown]
# #### Since New York is divided by borough, each their own county, they need to be webscraped individually.

# %%
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighborhoods_in_the_Bronx").text

# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
bx = pd.DataFrame({"Neighborhood": neighborhoodList})


bx['Neighborhood'] = bx['Neighborhood'].astype(str).str[1:]


sep = '('
bx['Neighborhood'] = bx['Neighborhood'].apply(lambda x: x.split(sep,1)[0])
bx['Neighborhood'] = bx['Neighborhood'].str.strip()

# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Bronx, New York'.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in bx["Neighborhood"].tolist() ]

# %%
# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# merge the coordinates into the original dataframe
bx['Latitude'] = df_coords['Latitude']
bx['Longitude'] = df_coords['Longitude']

# %%
# save the DataFrame as CSV file
bx.to_csv("bx_neighborhoods.csv", index=False)

# check the neighborhoods and the coordinates
print(bx.shape)
bx
# Out:
# (31, 3)
#                    Neighborhood   Latitude  Longitude
# 0          Bedford Park, Bronx‎  40.869990  -73.88573
# 1               Belmont, Bronx‎  40.855460  -73.88569
# 2           City Island, Bronx‎  40.855640  -73.79171
# 3            Co-op City, Bronx‎  40.879939  -73.82317
# 4             Concourse, Bronx‎  40.827630  -73.92533
# 5           Eastchester, Bronx‎  40.888110  -73.82835
# 6               Fordham, Bronx‎  40.858940  -73.89885
# 7            Highbridge, Bronx‎  40.842117  -73.92820
# 8           Hunts Point, Bronx‎  40.812420  -73.88450
# 9           Jerome Park, Bronx‎  40.865470  -73.89896
# 10  Kingsbridge Heights, Bronx‎  40.870030  -73.89821
# 11          Kingsbridge, Bronx‎  40.883700  -73.90273
# 12             Longwood, Bronx‎  40.817480  -73.89816
# 13              Melrose, Bronx‎  40.824430  -73.91070
# 14       Morris Heights, Bronx‎  40.849710  -73.91985
# 15          Morris Park, Bronx‎  40.848300  -73.85513
# 16           Morrisania, Bronx‎  40.828860  -73.90680
# 17           Mott Haven, Bronx‎  40.808990  -73.92295
# 18              Norwood, Bronx‎  40.878690  -73.87929
# 19          Parkchester, Bronx‎  40.839130  -73.86109
# 20          Port Morris, Bronx‎  40.801340  -73.90996
# 21            Riverdale, Bronx‎  40.900190  -73.90697
# 22            Soundview, Bronx‎  40.822910  -73.86827
# 23       Spuyten Duyvil, Bronx‎  40.881180  -73.91773
# 24         Throggs Neck, Bronx‎  40.821138  -73.81281
# 25              Tremont, Bronx‎  40.849390  -73.90627
# 26   University Heights, Bronx‎  40.860190  -73.90971
# 27             Van Nest, Bronx‎  40.849030  -73.86463
# 28           West Farms, Bronx‎  40.839760  -73.87793
# 29   Westchester Square, Bronx‎  40.841120  -73.84281
# 30       Williamsbridge, Bronx‎  40.877250  -73.85660

# %% [markdown]
# ## Manhattan

# %%
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighborhoods_in_Manhattan").text

# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
mh = pd.DataFrame({"Neighborhood": neighborhoodList})


mh['Neighborhood'] = mh['Neighborhood'].astype(str).str[1:]


sep = '('
mh['Neighborhood'] = mh['Neighborhood'].apply(lambda x: x.split(sep,1)[0])
mh['Neighborhood'] = mh['Neighborhood'].str.strip()

# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Manhattan, New York'.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in mh["Neighborhood"].tolist() ]

# %%
# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# merge the coordinates into the original dataframe
mh['Latitude'] = df_coords['Latitude']
mh['Longitude'] = df_coords['Longitude']

# save the DataFrame as CSV file
mh.to_csv("mh_neighborhoods.csv", index=False)

# check the neighborhoods and the coordinates
print(mh.shape)
mh
# Out:
# (44, 3)
#                         Neighborhood   Latitude   Longitude
# 0                 Battery Park City‎  40.711310  -74.015900
# 1                            Bowery‎  40.723280  -73.992893
# 2                Chelsea, Manhattan‎  40.746100  -74.000450
# 3           Civic Center, Manhattan‎  40.713370  -74.003800
# 4                   Columbus Circle‎  40.765730  -73.983380
# 5                       East Harlem‎  40.798280  -73.940810
# 6           East Village, Manhattan‎  40.728040  -73.984990
# 7     Financial District, Manhattan‎  40.708260  -74.014100
# 8            Five Points, Manhattan‎  45.858578 -111.328778
# 9                 Flatiron District‎  40.739420  -73.990350
# 10                 Governors Island‎  40.691850  -74.013360
# 11                    Gramercy Park‎  40.738212  -73.985662
# 12                Greenwich Village‎  40.728560  -74.004890
# 13      Hamilton Heights, Manhattan‎  40.822380  -73.949680
# 14                           Harlem‎  40.808810  -73.947960
# 15        Hell's Kitchen, Manhattan‎  40.758110  -74.000280
# 16                    Hudson Square‎  43.153556  -77.601247
# 17          Hudson Yards, Manhattan‎  40.753416  -74.000022
# 18                Inwood, Manhattan‎  40.714500  -74.006010
# 19              Kips Bay, Manhattan‎  40.714500  -74.006010
# 20        Lincoln Square, Manhattan‎  40.773212  -73.981866
# 21                     Little Spain‎  40.714500  -74.006010
# 22                  Lower East Side‎  40.719130  -73.987630
# 23                  Lower Manhattan‎  40.719130  -73.987630
# 24  Meatpacking District, Manhattan‎  40.740660  -74.006820
# 25                Midtown Manhattan‎  40.760310  -74.002850
# 26   Morningside Heights, Manhattan‎  40.810530  -73.962060
# 27           Murray Hill, Manhattan‎  40.748550  -73.976050
# 28                           Nolita‎  40.723200  -73.995310
# 29               Pennsylvania Plaza‎  40.749922  -73.992758
# 30                 Roosevelt Island‎  40.764560  -73.947320
# 31             Rose Hill, Manhattan‎  40.714500  -74.006010
# 32                  SoHo, Manhattan‎  40.710369  -73.992219
# 33           South Ferry, Manhattan‎  40.701142  -74.013903
# 34      Theater District, Manhattan‎  40.758880  -73.984820
# 35                          Tribeca‎  40.718540  -74.008880
# 36          Union Square, Manhattan‎  40.736870  -73.989960
# 37                  Upper East Side‎  40.770620  -73.957030
# 38                  Upper Manhattan‎  40.820520  -73.943830
# 39                  Upper West Side‎  40.792510  -73.973200
# 40    Washington Heights, Manhattan‎  40.849830  -73.936030
# 41                     West Village‎  40.734970  -74.004830
# 42               World Trade Center‎  40.712569  -74.014081
# 43             Yorkville, Manhattan‎  40.778080  -73.948500

# %% [markdown]
# ## Brooklyn

# %%
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighborhoods_in_Brooklyn").text

# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
bk = pd.DataFrame({"Neighborhood": neighborhoodList})


bk['Neighborhood'] = bk['Neighborhood'].astype(str).str[1:]


sep = '('
bk['Neighborhood'] = bk['Neighborhood'].apply(lambda x: x.split(sep,1)[0])
bk['Neighborhood'] = bk['Neighborhood'].str.strip()

# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Brooklyn, New York'.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in bk["Neighborhood"].tolist() ]

# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# merge the coordinates into the original dataframe
bk['Latitude'] = df_coords['Latitude']
bk['Longitude'] = df_coords['Longitude']

# %%
bk = bk.drop(32,axis = 0)

# %%
# save the DataFrame as CSV file
bk.to_csv("bk_neighborhoods.csv", index=False)


# check the neighborhoods and the coordinates
print(bk.shape)
bk
# Out:
# (39, 3)
#                      Neighborhood   Latitude  Longitude
# 0            Bay Ridge, Brooklyn‎  40.619600 -74.027569
# 1   Bedford–Stuyvesant, Brooklyn‎  40.681945 -73.933294
# 2          Bensonhurst, Brooklyn‎  40.604820 -73.995280
# 3                    Boerum Hill‎  40.689430 -73.988010
# 4         Borough Park, Brooklyn‎  40.638820 -73.989120
# 5                 Brighton Beach‎  40.574570 -73.953430
# 6               Brooklyn Heights‎  40.695350 -73.994050
# 7             Brooklyn Navy Yard‎  40.705177 -73.971624
# 8          Brownsville, Brooklyn‎  40.671134 -73.913476
# 9             Bushwick, Brooklyn‎  40.713488 -73.941454
# 10            Canarsie, Brooklyn‎  40.632325 -73.892372
# 11     Carroll Gardens, Brooklyn‎  40.686610 -73.967540
# 12        Clinton Hill, Brooklyn‎  40.698656 -73.969738
# 13         Cobble Hill, Brooklyn‎  40.686730 -73.992101
# 14                  Coney Island‎  40.575500 -73.978450
# 15       Crown Heights, Brooklyn‎  40.665100 -73.948154
# 16       Cypress Hills, Brooklyn‎  40.690364 -73.877394
# 17             Downtown Brooklyn‎  40.693630 -73.982880
# 18       Dyker Heights, Brooklyn‎  40.618881 -74.008897
# 19       East Flatbush, Brooklyn‎  40.635995 -73.945082
# 20       East New York, Brooklyn‎  40.666470 -73.967231
# 21            Flatbush, Brooklyn‎  40.670758 -73.967745
# 22           Flatlands, Brooklyn‎  40.642624 -73.902259
# 23         Fort Greene, Brooklyn‎  40.686577 -73.976450
# 24             Gowanus, Brooklyn‎  40.651042 -74.010956
# 25           Gravesend, Brooklyn‎  40.586280 -73.998051
# 26          Greenpoint, Brooklyn‎  40.730603 -73.950032
# 27     Manhattan Beach, Brooklyn‎  40.577820 -73.943550
# 28         Marine Park, Brooklyn‎  40.604130 -73.931150
# 29             Midwood, Brooklyn‎  40.660050 -73.951579
# 30          Mill Basin, Brooklyn‎  40.613660 -73.906626
# 31                    Park Slope‎  40.670440 -73.987180
# 33    Prospect Heights, Brooklyn‎  40.700683 -73.987865
# 34            Red Hook, Brooklyn‎  40.691373 -73.988700
# 35            Sea Gate, Brooklyn‎  40.577602 -74.005746
# 36      Sheepshead Bay, Brooklyn‎  40.583580 -73.942480
# 37                South Brooklyn‎  40.683880 -73.995710
# 38         Sunset Park, Brooklyn‎  40.648410 -74.006660
# 39        Williamsburg, Brooklyn‎  40.700051 -73.962456

# %% [markdown]
# ## Queens

# %%
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighborhoods_in_Queens,_New_York").text

# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
qn = pd.DataFrame({"Neighborhood": neighborhoodList})

# %%
qn['Neighborhood'] = qn['Neighborhood'].astype(str).str[1:]

sep = '('
qn['Neighborhood'] = qn['Neighborhood'].apply(lambda x: x.split(sep,1)[0])
qn['Neighborhood'] = qn['Neighborhood'].str.strip()

# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Brooklyn, New York'.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in qn["Neighborhood"].tolist() ]

# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# merge the coordinates into the original dataframe
qn['Latitude'] = df_coords['Latitude']
qn['Longitude'] = df_coords['Longitude']

# %%
qn = qn.drop([20,22],axis = 0)

# %%
# save the DataFrame as CSV file
qn.to_csv("qn_neighborhoods.csv", index=False)


# check the neighborhoods and the coordinates
print(qn.shape)
qn
# Out:
# (27, 3)
#                        Neighborhood   Latitude  Longitude
# 0                  Astoria, Queens‎  40.772050 -73.926060
# 1                  Bayside, Queens‎  40.777310 -73.780680
# 2                   Corona, Queens‎  40.746370 -73.854830
# 3   Douglaston–Little Neck, Queens‎  40.768561 -73.747657
# 4            East Elmhurst, Queens‎  40.764390 -73.874020
# 5                 Elmhurst, Queens‎  40.743610 -73.884330
# 6            Floral Park, New York‎  40.664506 -73.979842
# 7                 Flushing, Queens‎  40.706477 -73.925219
# 8             Forest Hills, Queens‎  40.722660 -73.847910
# 9            Fresh Meadows, Queens‎  40.741620 -73.782990
# 10               Glen Oaks, Queens‎  40.748000 -73.713240
# 11                Glendale, Queens‎  40.701410 -73.887200
# 12            Howard Beach, Queens‎  40.654830 -73.846020
# 13         Jackson Heights, Queens‎  40.749400 -73.887560
# 14                 Jamaica, Queens‎  40.687666 -73.877538
# 15       Kew Gardens Hills, Queens‎  40.730020 -73.823400
# 16             Kew Gardens, Queens‎  40.708650 -73.828910
# 17                Long Island City‎  40.750720 -73.941030
# 18                 Maspeth, Queens‎  40.727290 -73.895440
# 19          Middle Village, Queens‎  40.712380 -73.882700
# 21              Ozone Park, Queens‎  40.680120 -73.847360
# 23           Richmond Hill, Queens‎  40.700540 -73.828060
# 24               Ridgewood, Queens‎  40.698129 -73.910641
# 25                Rockaway, Queens‎  40.685531 -73.863764
# 26              Whitestone, Queens‎  40.788630 -73.813730
# 27               Woodhaven, Queens‎  40.692630 -73.861020
# 28                Woodside, Queens‎  40.746960 -73.902790

# %% [markdown]
# ## Staten Island

# %%
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighborhoods_in_Staten_Island").text

# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
si = pd.DataFrame({"Neighborhood": neighborhoodList})

# %%
si = si.drop([0],axis = 0)

# %%
si
# Out:
#                         Neighborhood
# 1            Annadale, Staten Island
# 2       Arden Heights, Staten Island
# 3           Arlington, Staten Island
# 4            Arrochar, Staten Island
# 5                       Aspen Knolls
# 6         Bay Terrace, Staten Island
# 7          Bloomfield, Staten Island
# 8    Brighton Heights, Staten Island
# 9          Bulls Head, Staten Island
# 10  Castleton Corners, Staten Island
# 11         Charleston, Staten Island
# 12            Chelsea, Staten Island
# 13            Clifton, Staten Island
# 14            Concord, Staten Island
# 15       Dongan Hills, Staten Island
# 16         East Shore, Staten Island
# 17        Egbertville, Staten Island
# 18           Elm Park, Staten Island
# 19        Eltingville, Staten Island
# 20       Emerson Hill, Staten Island
# 21                    Fort Wadsworth
# 22       Graniteville, Staten Island
# 23         Grant City, Staten Island
# 24           Grasmere, Staten Island
# 25        Great Kills, Staten Island
# 26         Greenridge, Staten Island
# 27        Grymes Hill, Staten Island
# 28  Heartland Village, Staten Island
# 29           Huguenot, Staten Island
# 30    Lighthouse Hill, Staten Island
# 31         Livingston, Staten Island
# 32      Manor Heights, Staten Island
# 33    Mariners Harbor, Staten Island
# 34     Meiers Corners, Staten Island
# 35         Mid-Island, Staten Island
# 36      Midland Beach, Staten Island
# 37       New Brighton, Staten Island
# 38                    New Dorp Beach
# 39           New Dorp, Staten Island
# 40    New Springville, Staten Island
# 41        North Shore, Staten Island
# 42            Oakwood, Staten Island
# 43          Old Place, Staten Island
# 44           Old Town, Staten Island
# 45    Pleasant Plains, Staten Island
# 46         Port Ivory, Staten Island
# 47      Port Richmond, Staten Island
# 48       Prince's Bay, Staten Island
# 49      Randall Manor, Staten Island
# 50    Richmond Valley, Staten Island
# 51       Richmondtown, Staten Island
# 52           Rosebank, Staten Island
# 53          Rossville, Staten Island
# 54         St. George, Staten Island
# 55        Shore Acres, Staten Island
# 56        Silver Lake, Staten Island
# 57        South Beach, Staten Island
# 58        South Shore, Staten Island
# 59                      Spanish Camp
# 60  Stapleton Heights, Staten Island
# 61          Stapleton, Staten Island
# 62          Sunnyside, Staten Island
# 63          Teleport (Staten Island)
# 64                         Todt Hill
# 65      Tompkinsville, Staten Island
# 66        Tottenville, Staten Island
# 67             Travis, Staten Island
# 68          Ward Hill, Staten Island
# 69  West New Brighton, Staten Island
# 70         West Shore, Staten Island
# 71        Westerleigh, Staten Island
# 72        Willowbrook, Staten Island
# 73            Woodrow, Staten Island

# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Staten Island, New York'.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in si["Neighborhood"].tolist() ]

# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# merge the coordinates into the original dataframe
si['Latitude'] = df_coords['Latitude']
si['Longitude'] = df_coords['Longitude']

# %%
si
# Out:
#                         Neighborhood   Latitude  Longitude
# 1            Annadale, Staten Island  40.559891 -74.198791
# 2       Arden Heights, Staten Island  40.642395 -74.110820
# 3           Arlington, Staten Island  40.642420 -74.075270
# 4            Arrochar, Staten Island  40.562344 -74.184025
# 5                       Aspen Knolls  40.554536 -74.135866
# 6         Bay Terrace, Staten Island  40.610592 -74.179655
# 7          Bloomfield, Staten Island  40.504032 -74.243297
# 8    Brighton Heights, Staten Island  40.642420 -74.075270
# 9          Bulls Head, Staten Island  40.621220 -74.129150
# 10  Castleton Corners, Staten Island  40.549418 -74.216839
# 11         Charleston, Staten Island  40.504305 -74.244341
# 12            Chelsea, Staten Island  40.612400 -74.072071
# 13            Clifton, Staten Island  40.598612 -74.100965
# 14            Concord, Staten Island  40.588006 -74.100679
# 15       Dongan Hills, Staten Island  40.505830 -74.250981
# 16         East Shore, Staten Island  40.642420 -74.075270
# 17        Egbertville, Staten Island  40.638460 -74.114003
# 18           Elm Park, Staten Island  40.557257 -74.167151
# 19        Eltingville, Staten Island  40.604030 -74.100333
# 20       Emerson Hill, Staten Island  40.606590 -74.060640
# 21                    Fort Wadsworth  40.624840 -74.150810
# 22       Graniteville, Staten Island  40.642420 -74.075270
# 23         Grant City, Staten Island  40.601545 -74.084130
# 24           Grasmere, Staten Island  40.547909 -74.143449
# 25        Great Kills, Staten Island  40.559987 -74.168213
# 26         Greenridge, Staten Island  40.623330 -74.090957
# 27        Grymes Hill, Staten Island  40.590996 -74.164409
# 28  Heartland Village, Staten Island  40.537656 -74.194674
# 29           Huguenot, Staten Island  40.575929 -74.139884
# 30    Lighthouse Hill, Staten Island  40.602131 -74.128523
# 31         Livingston, Staten Island  40.611111 -74.121773
# 32      Manor Heights, Staten Island  40.635487 -74.152474
# 33    Mariners Harbor, Staten Island  40.612236 -74.130518
# 34     Meiers Corners, Staten Island  40.642420 -74.075270
# 35         Mid-Island, Staten Island  40.569820 -74.090920
# 36      Midland Beach, Staten Island  40.504032 -74.243297
# 37       New Brighton, Staten Island  40.564860 -74.103760
# 38                    New Dorp Beach  40.569396 -74.107745
# 39           New Dorp, Staten Island  40.594268 -74.161182
# 40    New Springville, Staten Island  40.606885 -74.059182
# 41        North Shore, Staten Island  40.629750 -74.101260
# 42            Oakwood, Staten Island  40.642420 -74.075270
# 43          Old Place, Staten Island  40.595961 -74.087063
# 44           Old Town, Staten Island  40.523709 -74.219393
# 45    Pleasant Plains, Staten Island  40.638802 -74.138537
# 46         Port Ivory, Staten Island  40.634250 -74.184650
# 47      Port Richmond, Staten Island  40.629515 -74.150260
# 48       Prince's Bay, Staten Island  40.632774 -74.099126
# 49      Randall Manor, Staten Island  40.520915 -74.235157
# 50    Richmond Valley, Staten Island  40.570526 -74.146416
# 51       Richmondtown, Staten Island  40.614125 -74.067395
# 52           Rosebank, Staten Island  40.548691 -74.210739
# 53          Rossville, Staten Island  40.592992 -74.105458
# 54         St. George, Staten Island  40.609000 -74.061057
# 55        Shore Acres, Staten Island  40.632225 -74.093716
# 56        Silver Lake, Staten Island  40.590160 -74.066260
# 57        South Beach, Staten Island  40.606111 -74.058614
# 58        South Shore, Staten Island  40.523906 -74.170617
# 59                      Spanish Camp  40.573653 -74.091128
# 60  Stapleton Heights, Staten Island  40.627250 -74.075240
# 61          Stapleton, Staten Island  40.614462 -74.099608
# 62          Sunnyside, Staten Island  40.605950 -74.177222
# 63          Teleport (Staten Island)  40.598710 -74.099190
# 64                         Todt Hill  40.638094 -74.077211
# 65      Tompkinsville, Staten Island  40.506920 -74.253780
# 66        Tottenville, Staten Island  40.593655 -74.165770
# 67             Travis, Staten Island  40.632880 -74.082952
# 68          Ward Hill, Staten Island  40.633485 -74.118298
# 69  West New Brighton, Staten Island  40.557574 -74.204474
# 70         West Shore, Staten Island  40.618020 -74.132850
# 71        Westerleigh, Staten Island  40.603201 -74.141223
# 72        Willowbrook, Staten Island  40.550491 -74.187332
# 73            Woodrow, Staten Island        NaN        NaN

# %%
# save the DataFrame as CSV file
si.to_csv("si_neighborhoods.csv", index=False)


# check the neighborhoods and the coordinates
print(si.shape)
si
# Out:
# (73, 3)
#                         Neighborhood   Latitude  Longitude
# 1            Annadale, Staten Island  40.559891 -74.198791
# 2       Arden Heights, Staten Island  40.642395 -74.110820
# 3           Arlington, Staten Island  40.642420 -74.075270
# 4            Arrochar, Staten Island  40.562344 -74.184025
# 5                       Aspen Knolls  40.554536 -74.135866
# 6         Bay Terrace, Staten Island  40.610592 -74.179655
# 7          Bloomfield, Staten Island  40.504032 -74.243297
# 8    Brighton Heights, Staten Island  40.642420 -74.075270
# 9          Bulls Head, Staten Island  40.621220 -74.129150
# 10  Castleton Corners, Staten Island  40.549418 -74.216839
# 11         Charleston, Staten Island  40.504305 -74.244341
# 12            Chelsea, Staten Island  40.612400 -74.072071
# 13            Clifton, Staten Island  40.598612 -74.100965
# 14            Concord, Staten Island  40.588006 -74.100679
# 15       Dongan Hills, Staten Island  40.505830 -74.250981
# 16         East Shore, Staten Island  40.642420 -74.075270
# 17        Egbertville, Staten Island  40.638460 -74.114003
# 18           Elm Park, Staten Island  40.557257 -74.167151
# 19        Eltingville, Staten Island  40.604030 -74.100333
# 20       Emerson Hill, Staten Island  40.606590 -74.060640
# 21                    Fort Wadsworth  40.624840 -74.150810
# 22       Graniteville, Staten Island  40.642420 -74.075270
# 23         Grant City, Staten Island  40.601545 -74.084130
# 24           Grasmere, Staten Island  40.547909 -74.143449
# 25        Great Kills, Staten Island  40.559987 -74.168213
# 26         Greenridge, Staten Island  40.623330 -74.090957
# 27        Grymes Hill, Staten Island  40.590996 -74.164409
# 28  Heartland Village, Staten Island  40.537656 -74.194674
# 29           Huguenot, Staten Island  40.575929 -74.139884
# 30    Lighthouse Hill, Staten Island  40.602131 -74.128523
# 31         Livingston, Staten Island  40.611111 -74.121773
# 32      Manor Heights, Staten Island  40.635487 -74.152474
# 33    Mariners Harbor, Staten Island  40.612236 -74.130518
# 34     Meiers Corners, Staten Island  40.642420 -74.075270
# 35         Mid-Island, Staten Island  40.569820 -74.090920
# 36      Midland Beach, Staten Island  40.504032 -74.243297
# 37       New Brighton, Staten Island  40.564860 -74.103760
# 38                    New Dorp Beach  40.569396 -74.107745
# 39           New Dorp, Staten Island  40.594268 -74.161182
# 40    New Springville, Staten Island  40.606885 -74.059182
# 41        North Shore, Staten Island  40.629750 -74.101260
# 42            Oakwood, Staten Island  40.642420 -74.075270
# 43          Old Place, Staten Island  40.595961 -74.087063
# 44           Old Town, Staten Island  40.523709 -74.219393
# 45    Pleasant Plains, Staten Island  40.638802 -74.138537
# 46         Port Ivory, Staten Island  40.634250 -74.184650
# 47      Port Richmond, Staten Island  40.629515 -74.150260
# 48       Prince's Bay, Staten Island  40.632774 -74.099126
# 49      Randall Manor, Staten Island  40.520915 -74.235157
# 50    Richmond Valley, Staten Island  40.570526 -74.146416
# 51       Richmondtown, Staten Island  40.614125 -74.067395
# 52           Rosebank, Staten Island  40.548691 -74.210739
# 53          Rossville, Staten Island  40.592992 -74.105458
# 54         St. George, Staten Island  40.609000 -74.061057
# 195        Shore Acres, Staten Island  40.632225  -74.093716
# 196        Silver Lake, Staten Island  40.590160  -74.066260
# 197        South Beach, Staten Island  40.606111  -74.058614
# 198        South Shore, Staten Island  40.523906  -74.170617
# 199                      Spanish Camp  40.573653  -74.091128
# 200  Stapleton Heights, Staten Island  40.627250  -74.075240
# 201          Stapleton, Staten Island  40.614462  -74.099608
# 202          Sunnyside, Staten Island  40.605950  -74.177222
# 203          Teleport (Staten Island)  40.598710  -74.099190
# 204                         Todt Hill  40.638094  -74.077211
# 205      Tompkinsville, Staten Island  40.506920  -74.253780
# 206        Tottenville, Staten Island  40.593655  -74.165770
# 207             Travis, Staten Island  40.632880  -74.082952
# 208          Ward Hill, Staten Island  40.633485  -74.118298
# 209  West New Brighton, Staten Island  40.557574  -74.204474
# 210         West Shore, Staten Island  40.618020  -74.132850
# 211        Westerleigh, Staten Island  40.603201  -74.141223
# 212        Willowbrook, Staten Island  40.550491  -74.187332
# 213            Woodrow, Staten Island        NaN         NaN

# %%
ny = ny.drop([39,47,213],axis= 0)

# %%
ny.to_csv('ny_neighborhood.csv',index=False)

# %% [markdown]
# ## Map the points using Folium

# %%
# get the coordinates of New York City
address = 'New York, New York'

geolocator = Nominatim(user_agent="coursera-capstone-project")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York, New York {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York, New York 40.7127281, -74.0060152.

# %%
# create map of Toronto using latitude and longitude values
map_ny = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(ny['Latitude'], ny['Longitude'], ny['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_ny)  
    
map_ny
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Do the Same with Los Angeles

# %% [markdown]
# #### This should be faster because the Wikipedia page isn't split by county here

# %%
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighborhoods_in_Los_Angeles").text

# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
la = pd.DataFrame({"Neighborhood": neighborhoodList})


la['Neighborhood'] = la['Neighborhood'].astype(str).str[1:]


sep = '('
la['Neighborhood'] = la['Neighborhood'].apply(lambda x: x.split(sep,1)[0])
la['Neighborhood'] = la['Neighborhood'].str.strip()

# %%
la
# Out:
#                                         Neighborhood
# 0                 Historic districts in Los Angeles‎
# 1    People by Los Angeles district or neighborhood‎
# 2   Los Angeles Historic Preservation Overlay Zones‎
# 3                               Central Los Angeles‎
# 4                 Districts of Downtown Los Angeles‎
# 5                              Eastside Los Angeles‎
# 6                             Northeast Los Angeles‎
# 7                             Northwest Los Angeles‎
# 8                               San Fernando Valley‎
# 9                                 South Los Angeles‎
# 10                                          Westside
# 11                              Arleta, Los Angeles‎
# 12                     Atwater Village, Los Angeles‎
# 13                       Baldwin Hills, Los Angeles‎
# 14                             Bel Air, Los Angeles‎
# 15                       Beverly Crest, Los Angeles‎
# 16                       Boyle Heights, Los Angeles‎
# 17                           Brentwood, Los Angeles‎
# 18                         Canoga Park, Los Angeles‎
# 19                        Century City, Los Angeles‎
# 20                          Chatsworth, Los Angeles‎
# 21                            Crenshaw, Los Angeles‎
# 22                        Cypress Park, Los Angeles‎
# 23                             Downtown Los Angeles‎
# 24                          Eagle Rock, Los Angeles‎
# 25                      East Hollywood, Los Angeles‎
# 26                           Echo Park, Los Angeles‎
# 27                           El Sereno, Los Angeles‎
# 28                        Elysian Park, Los Angeles‎
# 29                              Encino, Los Angeles‎
# 30                                   Exposition Park
# 31                             Fairfax, Los Angeles‎
# 32                       Glassell Park, Los Angeles‎
# 33                       Granada Hills, Los Angeles‎
# 34                        Hancock Park, Los Angeles‎
# 35                      Harbor Gateway, Los Angeles‎
# 36                     Harvard Heights, Los Angeles‎
# 37                       Highland Park, Los Angeles‎
# 38                                        Hollywood‎
# 39                                  Hollywood Hills‎
# 40                        Holmby Hills, Los Angeles‎
# 41                      Jefferson Park, Los Angeles‎
# 42                           Koreatown, Los Angeles‎
# 43                         Lake Balboa, Los Angeles‎
# 44                   Lake View Terrace, Los Angeles‎
# 45                       Laurel Canyon, Los Angeles‎
# 46                     Lincoln Heights, Los Angeles‎
# 47                           Los Feliz, Los Angeles‎
# 48                           Mar Vista, Los Angeles‎
# 49                            Mid-City, Los Angeles‎
# 50                        Mid-Wilshire, Los Angeles‎
# 51                       Mission Hills, Los Angeles‎
# 52                   Montecito Heights, Los Angeles‎
# 53                    Mount Washington, Los Angeles‎
# 54                       Neighborhoods in Hollywood‎
# 55                     North Hollywood, Los Angeles‎
# 56                          Northridge, Los Angeles‎
# 57                   Pacific Palisades, Los Angeles‎
# 58                             Pacoima, Los Angeles‎
# 59                               Palms, Los Angeles‎
# 60                       Panorama City, Los Angeles‎
# 61                          Pico-Union, Los Angeles‎
# 62                       Playa del Rey, Los Angeles‎
# 63                         Playa Vista, Los Angeles‎
# 64                        Porter Ranch, Los Angeles‎
# 65                    Public housing in Los Angeles‎
# 66                            Pueblo de Los Ángeles‎
# 67                         Rancho Park, Los Angeles‎
# 68                              Reseda, Los Angeles‎
# 69                           San Pedro, Los Angeles‎
# 70                            Sawtelle, Los Angeles‎
# 71                        Sherman Oaks, Los Angeles‎
# 72                         Silver Lake, Los Angeles‎
# 73                         Studio City, Los Angeles‎
# 74                          Sun Valley, Los Angeles‎
# 75                     Sunland-Tujunga, Los Angeles‎
# 76                              Sylmar, Los Angeles‎
# 77                             Tarzana, Los Angeles‎
# 78                         Toluca Lake, Los Angeles‎
# 79                     University Park, Los Angeles‎
# 80                            Van Nuys, Los Angeles‎
# 81                              Venice, Los Angeles‎
# 82                               Watts, Los Angeles‎
# 83                          West Adams, Los Angeles‎
# 84                          West Hills, Los Angeles‎
# 85                                 West Los Angeles‎
# 86                         Westchester, Los Angeles‎
# 87                            Westlake, Los Angeles‎
# 88                            Westwood, Los Angeles‎
# 89                          Wilmington, Los Angeles‎
# 90                            Wilshire, Los Angeles‎
# 91                            Winnetka, Los Angeles‎
# 92                      Woodland Hills, Los Angeles‎

# %%
la.drop([0,1,2],axis=0,inplace=True)

# %%
la
# Out:
#                           Neighborhood
# 3                 Central Los Angeles‎
# 4   Districts of Downtown Los Angeles‎
# 5                Eastside Los Angeles‎
# 6               Northeast Los Angeles‎
# 7               Northwest Los Angeles‎
# 8                 San Fernando Valley‎
# 9                   South Los Angeles‎
# 10                            Westside
# 11                Arleta, Los Angeles‎
# 12       Atwater Village, Los Angeles‎
# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Los Angeles, California'.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in la["Neighborhood"].tolist() ]

# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# merge the coordinates into the original dataframe
la['Latitude'] = df_coords['Latitude']
la['Longitude'] = df_coords['Longitude']

# %%
la
# Out:
#                           Neighborhood   Latitude   Longitude
# 3                 Central Los Angeles‎  33.960110 -118.269190
# 4   Districts of Downtown Los Angeles‎  33.920680 -118.272980
# 5                Eastside Los Angeles‎  34.181950 -118.359520
# 6               Northeast Los Angeles‎  33.974580 -118.300420
# 7               Northwest Los Angeles‎  33.804400 -118.214530
# 8                 San Fernando Valley‎  34.249050 -118.433490
# 9                   South Los Angeles‎  34.119700 -118.258870
# 10                            Westside  34.021570 -118.367650
# 11                Arleta, Los Angeles‎  34.083610 -118.434830
# 12       Atwater Village, Los Angeles‎  34.096533 -118.403295
# 13         Baldwin Hills, Los Angeles‎  34.040040 -118.210500
# 14               Bel Air, Los Angeles‎  34.066260 -118.470330
# 15         Beverly Crest, Los Angeles‎  34.274200 -118.596440
# 16         Boyle Heights, Los Angeles‎  34.059440 -118.412810
# 17             Brentwood, Los Angeles‎  34.276912 -118.444410
# 18           Canoga Park, Los Angeles‎  34.010710 -118.335120
# 19          Century City, Los Angeles‎  34.088300 -118.225570
# 20            Chatsworth, Los Angeles‎  34.048340 -118.255640
# 21              Crenshaw, Los Angeles‎  34.139270 -118.210870
# 22          Cypress Park, Los Angeles‎  34.090860 -118.293350
# 23               Downtown Los Angeles‎  34.076090 -118.255810
# 24            Eagle Rock, Los Angeles‎  34.076850 -118.179340
# 25        East Hollywood, Los Angeles‎  34.082500 -118.233200
# 26             Echo Park, Los Angeles‎  34.253545 -118.515524
# 27             El Sereno, Los Angeles‎  34.011410 -118.289970
# 28          Elysian Park, Los Angeles‎  34.076100 -118.361220
# 29                Encino, Los Angeles‎  34.081910 -118.225990
# 30                     Exposition Park  34.291370 -118.501900
# 31               Fairfax, Los Angeles‎  34.062370 -118.358090
# 32         Glassell Park, Los Angeles‎  33.854184 -118.303480
# 33         Granada Hills, Los Angeles‎  34.043390 -118.309030
# 34          Hancock Park, Los Angeles‎  34.115080 -118.183350
# 35        Harbor Gateway, Los Angeles‎  34.101720 -118.360600
# 36       Harvard Heights, Los Angeles‎  34.105240 -118.320650
# 37         Highland Park, Los Angeles‎  34.052901 -118.423903
# 38                          Hollywood‎  34.032640 -118.318020
# 39                    Hollywood Hills‎  34.055386 -118.308666
# 40          Holmby Hills, Los Angeles‎  34.207160 -118.501140
# 41        Jefferson Park, Los Angeles‎  34.054730 -118.279867
# 42             Koreatown, Los Angeles‎  34.106671 -118.367538
# 43           Lake Balboa, Los Angeles‎  34.069830 -118.211640
# 44     Lake View Terrace, Los Angeles‎  34.105410 -118.289240
# 45         Laurel Canyon, Los Angeles‎  34.004680 -118.429130
# 46       Lincoln Heights, Los Angeles‎  34.040210 -118.347610
# 47             Los Feliz, Los Angeles‎  34.052863 -118.458251
# 48             Mar Vista, Los Angeles‎  34.282571 -118.463050
# 49              Mid-City, Los Angeles‎  34.091980 -118.201010
# 50          Mid-Wilshire, Los Angeles‎  34.099040 -118.211340
# 51         Mission Hills, Los Angeles‎  34.090860 -118.293350
# 52     Montecito Heights, Los Angeles‎  34.210670 -118.348780
# 53      Mount Washington, Los Angeles‎  33.995307 -118.354261
# 54         Neighborhoods in Hollywood‎  34.037910 -118.537870
# 55       North Hollywood, Los Angeles‎  34.139280 -118.393140
# 56            Northridge, Los Angeles‎  34.019860 -118.420960
# 57     Pacific Palisades, Los Angeles‎  34.101647 -118.270037
# 58               Pacoima, Los Angeles‎  34.040050 -118.285260
# 59                 Palms, Los Angeles‎  33.994346 -118.462848
# 60         Panorama City, Los Angeles‎  33.976187 -118.428713
# 61            Pico-Union, Los Angeles‎  34.272242 -118.569440
# 62         Playa del Rey, Los Angeles‎  34.053610 -118.245500
# 63           Playa Vista, Los Angeles‎  34.057580 -118.238430
# 64          Porter Ranch, Los Angeles‎  34.045070 -118.419240
# 65      Public housing in Los Angeles‎  34.239005 -118.536085
# 66              Pueblo de Los Ángeles‎  34.005255 -118.271719
# 67           Rancho Park, Los Angeles‎  34.034610 -118.448170
# 68                Reseda, Los Angeles‎  34.150865 -118.469456
# 69             San Pedro, Los Angeles‎  34.082730 -118.273070
# 70              Sawtelle, Los Angeles‎  34.141730 -118.375705
# 71          Sherman Oaks, Los Angeles‎  34.232730 -118.395750
# 72           Silver Lake, Los Angeles‎  34.259140 -118.312880
# 73           Studio City, Los Angeles‎  34.205725 -118.447309
# 74            Sun Valley, Los Angeles‎  34.161970 -118.526155
# 75       Sunland-Tujunga, Los Angeles‎  34.152190 -118.349400
# 76                Sylmar, Los Angeles‎  34.023899 -118.284310
# 77               Tarzana, Los Angeles‎  34.201189 -118.448720
# 78           Toluca Lake, Los Angeles‎  33.987379 -118.473897
# 79       University Park, Los Angeles‎  33.941280 -118.239030
# 80              Van Nuys, Los Angeles‎  34.027980 -118.353140
# 81                Venice, Los Angeles‎  34.165451 -118.583663
# 82                 Watts, Los Angeles‎  34.046470 -118.433950
# 83            West Adams, Los Angeles‎  33.959730 -118.413690
# 84            West Hills, Los Angeles‎  34.053710 -118.271300
# 85                   West Los Angeles‎  34.061680 -118.445450
# 86           Westchester, Los Angeles‎  33.981410 -118.238996
# 87              Westlake, Los Angeles‎  34.052863 -118.458251
# 88              Westwood, Los Angeles‎  34.232000 -118.571054
# 89            Wilmington, Los Angeles‎  34.104777 -118.364807
# 90              Wilshire, Los Angeles‎        NaN         NaN
# 91              Winnetka, Los Angeles‎        NaN         NaN
# 92        Woodland Hills, Los Angeles‎        NaN         NaN

# %%
la.drop([90,91,92],axis = 0, inplace = True)

# %%
la.to_csv('la_neighborhoods.csv',index=False)

# %%
# get the coordinates of New York City
address = 'Los Angeles, California'

geolocator = Nominatim(user_agent="coursera-capstone-project")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Los Angeles, California {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Los Angeles, California 34.0536909, -118.242766.

# %%
# create map of Toronto using latitude and longitude values
map_la = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(la['Latitude'], la['Longitude'], la['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_la)  
    
map_la
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
